# %%
print("Создание DataFrame")

data = [
    ["Али", 19, 85],
    ["Мария", 21, 92],
    ["Иван", 20, 78],
    ["Елена", 22, 95],
    ["Дмитрий", 18, 88]
]

print("Name\tAge\tScore")
print("-------------------")
for row in data:
    print(f"{row[0]}\t{row[1]}\t{row[2]}")
# Out:
# Создание DataFrame
# Name	Age	Score
# -------------------
# Али	19	85
# Мария	21	92
# Иван	20	78
# Елена	22	95
# Дмитрий	18	88
