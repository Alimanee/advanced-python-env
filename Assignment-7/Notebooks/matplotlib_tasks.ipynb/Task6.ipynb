# %%
print("Линейный график")

students = ["Али", "Мария", "Иван", "Елена", "Дмитрий"]
scores = [85, 92, 78, 95, 88]

print("Ось X (студенты):", students)
print("Ось Y (баллы):", scores)
print("График: точки соединены линией")
print("Маркеры: круги в каждой точке")
print("Заголовок: Баллы студентов")
print("Сетка: включена")
# Out:
# Линейный график
# Ось X (студенты): ['Али', 'Мария', 'Иван', 'Елена', 'Дмитрий']
# Ось Y (баллы): [85, 92, 78, 95, 88]
# График: точки соединены линией
# Маркеры: круги в каждой точке
# Заголовок: Баллы студентов
# Сетка: включена
